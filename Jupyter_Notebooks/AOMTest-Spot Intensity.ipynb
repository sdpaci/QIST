# %%
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import glob
import time
plt.rcParams["figure.figsize"] = (3,3)

print (time.ctime())
# Out:
# Fri Feb 28 14:49:15 2020

# %%
file1 = "/home/andrei/Data/TPX3/CHIP0/Test/8x8Grid_visEq_1s_W0028_F03-200228-095644-1_cent.csv"

print (file1, time.ctime())

data1=np.loadtxt(file1, dtype= float, delimiter=",", usecols = (0,1,2,3,4,5))

#print data
y1   = data1[:, 0]
x1   = data1[:, 1]
t1   = data1[:, 2]
a1   = data1[:, 3]
A1   = data1[:, 4]
n1   = data1[:, 5]

for i in range(0,20):
    print (i, x1[i],y1[i],t1[i],a1[i],A1[i],n1[i])
    
print (len(t1), time.ctime())

file2 = "/home/andrei/Data/TPX3/CHIP0/Test/8x8Grid_SettingsEq_1s_W0028_F03-200228-100050-1_cent.csv"

print (file2, time.ctime())

data2=np.loadtxt(file2, dtype= float, delimiter=",", usecols = (0,1,2,3,4,5))

#print data
y2   = data2[:, 0]
x2   = data2[:, 1]
t2   = data2[:, 2]
a2   = data2[:, 3]
A2   = data2[:, 4]
n2   = data2[:, 5]

for i in range(0,20):
    print (i, x2[i],y2[i],t2[i],a2[i],A2[i],n2[i])
    
print (len(t2), time.ctime())
# Out:
# /home/andrei/Data/TPX3/CHIP0/Test/8x8Grid_visEq_1s_W0028_F03-200228-095644-1_cent.csv Fri Feb 28 14:52:36 2020
# 0 0.0 145.0 16607193344.0 25.0 25.0 1.0
# 1 78.0 196.0 16607195904.0 25.0 25.0 1.0
# 2 78.0 196.0 16607407360.0 25.0 25.0 1.0
# 3 78.0 196.0 16607505408.0 50.0 50.0 1.0
# 4 23.0 196.0 16607505920.0 25.0 25.0 1.0
# 5 44.0 232.0 16607570176.0 50.0 50.0 1.0
# 6 13.0 235.0 16607570944.0 25.0 25.0 1.0
# 7 78.0 196.0 16607613952.0 400.0 400.0 1.0
# 8 15.0 254.0 16607659264.0 25.0 25.0 1.0
# 9 0.0 145.0 16607951616.0 100.0 100.0 1.0
# 10 0.0 145.0 16608212736.0 150.0 150.0 1.0
# 11 0.0 145.0 16608477440.0 25.0 25.0 1.0
# 12 0.0 145.0 16609655552.0 175.0 175.0 1.0
# 13 0.0 145.0 16610017024.0 25.0 25.0 1.0
# 14 0.0 145.0 16610802176.0 25.0 25.0 1.0
# 15 0.0 145.0 16611377152.0 150.0 150.0 1.0
# 16 0.0 145.0 16611587584.0 150.0 150.0 1.0
# 17 0.0 145.0 16611927040.0 175.0 175.0 1.0
# 18 0.0 145.0 16613162240.0 175.0 175.0 1.0
# 19 116.0 254.0 16614778112.0 100.0 100.0 1.0
# ...

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

h = ax0.hist2d(x1, y1, bins = 256, range = [(0, 256), (0, 256)])
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(x1, y1, bins = 256, range = [(0, 256), (0, 256)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)
fig.tight_layout()
plt.show()

# %%
GridX1min = 57
GridX1max = 107
GridY1min = 151
GridY1max = 201

fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

h = ax0.hist2d(x1, y1, bins = GridX1max-GridX1min, range = [(GridX1min, GridX1max), (GridY1min, GridY1max)])
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(x1, y1, bins = GridX1max-GridX1min, range = [(GridX1min, GridX1max), (GridY1min, GridY1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

fig.tight_layout()
plt.show()

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

h = ax0.hist2d(x2, y2, bins = 256, range = [(0, 256), (0, 256)])
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(x2, y2, bins = 256, range = [(0, 256), (0, 256)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)
fig.tight_layout()
plt.show()

# %%
GridX2min = 57
GridX2max = 107
GridY2min = 151
GridY2max = 201

fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

h = ax0.hist2d(x2, y2, bins = GridX2max-GridX2min, range = [(GridX2min, GridX2max), (GridY2min, GridY2max)])
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(x2, y2, bins = GridX2max-GridX2min, range = [(GridX2min, GridX2max), (GridY2min, GridY2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

fig.tight_layout()
plt.show()

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(t1/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()

#fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(tt/4096.*25., bins = 100, color = 'r', ec = 'k')
#plt.title("TOA", fontsize = 12) # change the title
#plt.xlabel('TOA, ns',fontsize = 12)
#plt.ylabel('counts',fontsize = 12)
#plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(t/4096.*25., bins = 10, range = (0.5E+9, 1.5E+9), color = 'r', ec = 'k')
plt.hist(t1/4096.*25., bins = 1000, range = (-1.E+9, 1.E+9), color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(t2/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()

#fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(tt/4096.*25., bins = 100, color = 'r', ec = 'k')
#plt.title("TOA", fontsize = 12) # change the title
#plt.xlabel('TOA, ns',fontsize = 12)
#plt.ylabel('counts',fontsize = 12)
#plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(t/4096.*25., bins = 10, range = (0.5E+9, 1.5E+9), color = 'r', ec = 'k')
plt.hist(t2/4096.*25., bins = 1000, range = (-1.E+9, 1.E+9), color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()

# %%
#Display Row 1

x1min = 78; x1max = 83;
y1min = 191; y1max = 196;

x2min = 84; x2max = 89;
y2min = 191; y2max = 196;

x3min = 89; x3max = 94;
y3min = 191; y3max = 196;

x4min = 95; x4max = 100;
y4min = 191; y4max = 196;

x5min = 100; x5max = 105;
y5min = 191; y5max = 196;

x6min = 106; x6max = 111;
y6min = 191; y6max = 196;

x7min = 111; x7max = 116;
y7min = 191; y7max = 196;

x8min = 116; x8max = 121;
y8min = 191; y8max = 196;

fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax1.hist2d(x1, y1, bins = x1max-x1min, range = [(x1min, x1max), (y1min, y1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

h = ax2.hist2d(x1, y1, bins = x2max-x2min, range = [(x2min, x2max), (y2min, y2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax2)

h = ax3.hist2d(x1, y1, bins = x3max-x3min, range = [(x3min, x3max), (y3min, y3max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax3)

h = ax4.hist2d(x1, y1, bins = x4max-x4min, range = [(x4min, x4max), (y4min, y4max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax4)

fig.tight_layout()
plt.show()

fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax5.hist2d(x1, y1, bins = x5max-x5min, range = [(x5min, x5max), (y5min, y5max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax5)

h = ax6.hist2d(x1, y1, bins = x6max-x6min, range = [(x6min, x6max), (y6min, y6max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax6)

h = ax7.hist2d(x1, y1, bins = x7max-x7min, range = [(x7min, x7max), (y7min, y7max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax7)

h = ax8.hist2d(x1, y1, bins = x8max-x8min, range = [(x8min, x8max), (y8min, y8max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax8)

fig.tight_layout()
plt.show()
# Out:
# /home/andrei/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
# /home/andrei/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# /home/andrei/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:53: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
# /home/andrei/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:53: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# /home/andrei/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:56: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
# ...

# %%
#Display Row 2

x9min = 185; x9max = 205;
y9min = 187; y9max = 207;

x10min = 50; x10max = 70;
y10min = 97; y10max = 117;

x11min = 185; x11max = 205;
y11min = 187; y11max = 207;

x12min = 50; x12max = 70;
y12min = 97; y12max = 117;

x13min = 185; x13max = 205;
y13min = 187; y13max = 207;

x14min = 50; x14max = 70;
y14min = 97; y14max = 117;

x15min = 185; x15max = 205;
y15min = 187; y15max = 207;

x16min = 185; x16max = 205;
y16min = 187; y16max = 207;


fig, (ax9, ax10, ax11, ax12) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax9.hist2d(x1, y1, bins = 20, range = [(x9min, x9max), (y9min, y9max)])
fig.colorbar(h[3], ax = ax9)

h = ax10.hist2d(x1, y1, bins = 20, range = [(x10min, x10max), (y10min, y10max)])
fig.colorbar(h[3], ax = ax10)

h = ax11.hist2d(x1, y1, bins = 20, range = [(x11min, x11max), (y11min, y11max)])
fig.colorbar(h[3], ax = ax11)

h = ax12.hist2d(x1, y1, bins = 20, range = [(x12min, x12max), (y12min, y12max)])
fig.colorbar(h[3], ax = ax12)

fig.tight_layout()
plt.show()

fig, (ax13, ax14, ax15, ax16) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax13.hist2d(x1, y1, bins = 20, range = [(x13min, x13max), (y13min, y13max)])
fig.colorbar(h[3], ax = ax13)

h = ax14.hist2d(x1, y1, bins = 20, range = [(x14min, x14max), (y14min, y14max)])
fig.colorbar(h[3], ax = ax14)

h = ax15.hist2d(x1, y1, bins = 20, range = [(x15min, x15max), (y15min, y15max)])
fig.colorbar(h[3], ax = ax15)

h = ax16.hist2d(x1, y1, bins = 20, range = [(x16min, x16max), (y16min, y16max)])
fig.colorbar(h[3], ax = ax16)

fig.tight_layout()
plt.show()

# %%
#Display Row 3

x17min = 185; x17max = 205;
y17min = 187; y17max = 207;

x18min = 50; x18max = 70;
y18min = 97; y18max = 117;

x19min = 185; x19max = 205;
y19min = 187; y19max = 207;

x20min = 50; x20max = 70;
y20min = 97; y20max = 117;

x21min = 185; x21max = 205;
y21min = 187; y21max = 207;

x22min = 50; x22max = 70;
y22min = 97; y22max = 117;

x23min = 185; x23max = 205;
y23min = 187; y23max = 207;

x24min = 185; x24max = 205;
y24min = 187; y24max = 207;


fig, (ax17, ax18, ax19, ax20) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax17.hist2d(x1, y1, bins = 20, range = [(x17min, x17max), (y17min, y17max)])
fig.colorbar(h[3], ax = ax17)

h = ax18.hist2d(x1, y1, bins = 20, range = [(x18min, x18max), (y18min, y18max)])
fig.colorbar(h[3], ax = ax18)

h = ax19.hist2d(x1, y1, bins = 20, range = [(x19min, x19max), (y19min, y19max)])
fig.colorbar(h[3], ax = ax19)

h = ax20.hist2d(x1, y1, bins = 20, range = [(x20min, x20max), (y20min, y20max)])
fig.colorbar(h[3], ax = ax20)

fig.tight_layout()
plt.show()

fig, (ax21, ax22, ax23, ax24) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax21.hist2d(x1, y1, bins = 20, range = [(x21min, x21max), (y21min, y21max)])
fig.colorbar(h[3], ax = ax21)

h = ax22.hist2d(x1, y1, bins = 20, range = [(x22min, x22max), (y22min, y22max)])
fig.colorbar(h[3], ax = ax22)

h = ax23.hist2d(x1, y1, bins = 20, range = [(x23min, x23max), (y23min, y23max)])
fig.colorbar(h[3], ax = ax23)

h = ax24.hist2d(x1, y1, bins = 20, range = [(x24min, x24max), (y24min, y24max)])
fig.colorbar(h[3], ax = ax24)

fig.tight_layout()
plt.show()

# %%
#Display row 4

x25min = 185; x25max = 205;
y25min = 187; y25max = 207;

x26min = 50; x26max = 70;
y26min = 97; y26max = 117;

x27min = 185; x27max = 205;
y27min = 187; y27max = 207;

x28min = 50; x28max = 70;
y28min = 97; y28max = 117;

x29min = 185; x29max = 205;
y29min = 187; y29max = 207;

x30min = 50; x30max = 70;
y30min = 97; y30max = 117;

x31min = 185; x31max = 205;
y31min = 187; y31max = 207;

x32min = 185; x32max = 205;
y32min = 187; y32max = 207;


fig, (ax25, ax26, ax27, ax28) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax25.hist2d(x1, y1, bins = 20, range = [(x25min, x25max), (y25min, y25max)])
fig.colorbar(h[3], ax = ax25)

h = ax26.hist2d(x1, y1, bins = 20, range = [(x26min, x26max), (y26min, y26max)])
fig.colorbar(h[3], ax = ax26)

h = ax27.hist2d(x1, y1, bins = 20, range = [(x27min, x27max), (y27min, y27max)])
fig.colorbar(h[3], ax = ax27)

h = ax28.hist2d(x1, y1, bins = 20, range = [(x28min, x28max), (y28min, y28max)])
fig.colorbar(h[3], ax = ax28)

fig.tight_layout()
plt.show()

fig, (ax29, ax30, ax31, ax32) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax29.hist2d(x1, y1, bins = 20, range = [(x29min, x29max), (y29min, y29max)])
fig.colorbar(h[3], ax = ax29)

h = ax30.hist2d(x1, y1, bins = 20, range = [(x30min, x30max), (y30min, y30max)])
fig.colorbar(h[3], ax = ax30)

h = ax31.hist2d(x1, y1, bins = 20, range = [(x31min, x31max), (y31min, y31max)])
fig.colorbar(h[3], ax = ax31)

h = ax32.hist2d(x1, y1, bins = 20, range = [(x32min, x32max), (y32min, y32max)])
fig.colorbar(h[3], ax = ax32)

fig.tight_layout()
plt.show()

# %%
#Display Row 5

x33min = 185; x33max = 205;
y33min = 187; y33max = 207;

x34min = 50; x34max = 70;
y34min = 97; y34max = 117;

x35min = 185; x35max = 205;
y35min = 187; y35max = 207;

x36min = 50; x36max = 70;
y36min = 97; y36max = 117;

x37min = 185; x37max = 205;
y37min = 187; y37max = 207;

x38min = 50; x38max = 70;
y38min = 97; y38max = 117;

x39min = 185; x39max = 205;
y31min = 187; y31max = 207;

x40min = 185; x40max = 205;
y40min = 187; y40max = 207;


fig, (ax33, ax34, ax35, ax36) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax33.hist2d(x1, y1, bins = 20, range = [(x33min, x33max), (y33min, y33max)])
fig.colorbar(h[3], ax = ax33)

h = ax34.hist2d(x1, y1, bins = 20, range = [(x34min, x34max), (y34min, y34max)])
fig.colorbar(h[3], ax = ax34)

h = ax35.hist2d(x1, y1, bins = 20, range = [(x35min, x35max), (y35min, y35max)])
fig.colorbar(h[3], ax = ax35)

h = ax36.hist2d(x1, y1, bins = 20, range = [(x36min, x36max), (y36min, y36max)])
fig.colorbar(h[3], ax = ax36)

fig.tight_layout()
plt.show()

fig, (ax37, ax38, ax39, ax40) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax37.hist2d(x1, y1, bins = 20, range = [(x37min, x37max), (y37min, y37max)])
fig.colorbar(h[3], ax = ax37)

h = ax38.hist2d(x1, y1, bins = 20, range = [(x38min, x38max), (y38min, y38max)])
fig.colorbar(h[3], ax = ax38)

h = ax39.hist2d(x1, y1, bins = 20, range = [(x39min, x39max), (y39min, y39max)])
fig.colorbar(h[3], ax = ax39)

h = ax40.hist2d(x1, y1, bins = 20, range = [(x40min, x40max), (y40min, y40max)])
fig.colorbar(h[3], ax = ax40)

fig.tight_layout()
plt.show()

# %%
#Display Row 6

x41min = 185; x41max = 205;
y41min = 187; y41max = 207;

x42min = 50; x42max = 70;
y42min = 97; y42max = 117;

x43min = 185; x43max = 205;
y43min = 187; y43max = 207;

x44min = 50; x44max = 70;
y44min = 97; y44max = 117;

x45min = 185; x45max = 205;
y45min = 187; y45max = 207;

x46min = 50; x46max = 70;
y46min = 97; y46max = 117;

x47min = 185; x47max = 205;
y47min = 187; y47max = 207;

x48min = 185; x48max = 205;
y48min = 187; y48max = 207;


fig, (ax41, ax42, ax43, ax44) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax41.hist2d(x1, y1, bins = 20, range = [(x41min, x41max), (y41min, y41max)])
fig.colorbar(h[3], ax = ax41)

h = ax42.hist2d(x1, y1, bins = 20, range = [(x42min, x42max), (y42min, y42max)])
fig.colorbar(h[3], ax = ax42)

h = ax43.hist2d(x1, y1, bins = 20, range = [(x43min, x43max), (y43min, y43max)])
fig.colorbar(h[3], ax = ax35)

h = ax44.hist2d(x1, y1, bins = 20, range = [(x44min, x44max), (y44min, y44max)])
fig.colorbar(h[3], ax = ax44)

fig.tight_layout()
plt.show()

fig, (ax45, ax46, ax47, ax48) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax45.hist2d(x1, y1, bins = 20, range = [(x45min, x45max), (y45min, y45max)])
fig.colorbar(h[3], ax = ax45)

h = ax46.hist2d(x1, y1, bins = 20, range = [(x46min, x46max), (y46min, y46max)])
fig.colorbar(h[3], ax = ax46)

h = ax47.hist2d(x1, y1, bins = 20, range = [(x47min, x47max), (y47min, y47max)])
fig.colorbar(h[3], ax = ax39)

h = ax48.hist2d(x1, y1, bins = 20, range = [(x48min, x48max), (y48min, y48max)])
fig.colorbar(h[3], ax = ax48)

fig.tight_layout()
plt.show()

# %%
#Display Row 7

x49min = 185; x49max = 205;
y49min = 187; y49max = 207;

x50min = 50; x50max = 70;
y50min = 97; y50max = 117;

x51min = 185; x51max = 205;
y51min = 187; y51max = 207;

x52min = 50; x52max = 70;
y52min = 97; y52max = 117;

x53min = 185; x53max = 205;
y53min = 187; y53max = 207;

x54min = 50; x54max = 70;
y54min = 97; y54max = 117;

x55min = 185; x55max = 205;
y55min = 187; y55max = 207;

x56min = 185; x56max = 205;
y56min = 187; y56max = 207;


fig, (ax49, ax50, ax51, ax52) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax49.hist2d(x1, y1, bins = 20, range = [(x49min, x49max), (y49min, y49max)])
fig.colorbar(h[3], ax = ax49)

h = ax50.hist2d(x1, y1, bins = 20, range = [(x50min, x50max), (y50min, y50max)])
fig.colorbar(h[3], ax = ax50)

h = ax51.hist2d(x1, y1, bins = 20, range = [(x51min, x51max), (y51min, y51max)])
fig.colorbar(h[3], ax = ax51)

h = ax52.hist2d(x1, y1, bins = 20, range = [(x52min, x52max), (y52min, y52max)])
fig.colorbar(h[3], ax = ax52)

fig.tight_layout()
plt.show()

fig, (ax53, ax54, ax55, ax56) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax53.hist2d(x1, y1, bins = 20, range = [(x53min, x53max), (y53min, y53max)])
fig.colorbar(h[3], ax = ax53)

h = ax54.hist2d(x1, y1, bins = 20, range = [(x54min, x54max), (y54min, y54max)])
fig.colorbar(h[3], ax = ax54)

h = ax55.hist2d(x1, y1, bins = 20, range = [(x55min, x55max), (y55min, y55max)])
fig.colorbar(h[3], ax = ax55)

h = ax56.hist2d(x1, y1, bins = 20, range = [(x56min, x56max), (y56min, y56max)])
fig.colorbar(h[3], ax = ax56)

fig.tight_layout()
plt.show()

# %%
#Display Row 8

x57min = 185; x57max = 205;
y57min = 187; y57max = 207;

x58min = 50; x58max = 70;
y58min = 97; y58max = 117;

x59min = 185; x59max = 205;
y59min = 187; y59max = 207;

x60min = 50; x60max = 70;
y60min = 97; y60max = 117;

x61min = 185; x61max = 205;
y61min = 187; y61max = 207;

x62min = 50; x62max = 70;
y62min = 97; y62max = 117;

x63min = 185; x63max = 205;
y63min = 187; y63max = 207;

x64min = 185; x64max = 205;
y64min = 187; y64max = 207;


fig, (ax57, ax58, ax59, ax60) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax57.hist2d(x1, y1, bins = 20, range = [(x57min, x57max), (y57min, y57max)])
fig.colorbar(h[3], ax = ax57)

h = ax58.hist2d(x1, y1, bins = 20, range = [(x58min, x58max), (y58min, y58max)])
fig.colorbar(h[3], ax = ax58)

h = ax59.hist2d(x1, y1, bins = 20, range = [(x59min, x59max), (y59min, y59max)])
fig.colorbar(h[3], ax = ax59)

h = ax60.hist2d(x1, y1, bins = 20, range = [(x60min, x60max), (y60min, y60max)])
fig.colorbar(h[3], ax = ax60)

fig.tight_layout()
plt.show()

fig, (ax61, ax62, ax63, ax64) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax61.hist2d(x1, y1, bins = 20, range = [(x61min, x61max), (y61min, y61max)])
fig.colorbar(h[3], ax = ax61)

h = ax62.hist2d(x1, y1, bins = 20, range = [(x62min, x62max), (y62min, y62max)])
fig.colorbar(h[3], ax = ax62)

h = ax63.hist2d(x1, y1, bins = 20, range = [(x63min, x63max), (y63min, y63max)])
fig.colorbar(h[3], ax = ax63)

h = ax64.hist2d(x1, y1, bins = 20, range = [(x64min, x64max), (y64min, y64max)])
fig.colorbar(h[3], ax = ax64)

fig.tight_layout()
plt.show()

# %%
#finds points in each projection histo peak
#Empty peak arrays
x1p1 = []; x1p2 = []; 

#Empty baseline arrays
x1b = [];

#Sorts points in x1 peaks
#Get range #s by above histos

for i in range(len(x1)-1):
    if (x1min <= x1[i] <= x1max):
        x1p1.append(x1[i])
        
    elif (x2min <= x1[i] <= x2max):
        x1p2.append(x1[i])
    
    else:
        x1b.append(x1[i])
        
print (len(x1p1), len(x1p2), len(x1b), time.ctime())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8444988a5c31> in <module>
#       9 #Get range #s by above histos
#      10
# ---> 11 for i in range(len(x1)-1):
#      12     if (x1min <= x1[i] <= x1max):
#      13         x1p1.append(x1[i])
#
# NameError: name 'x1' is not defined

# %%
fig, (ax0) = plt.subplots(ncols=1, figsize=(20, 6))

#ax0.hist(x1p1, bins = 256, range = (0, 256), alpha = 1, histtype = 'step')
#ax0.hist(x1p2, bins = 256, range = (0, 256), alpha = 1, histtype = 'step')
ax0.hist(x1b, bins = 256, range = (0, 256), alpha = 1, histtype = 'step')
#plt.ylim(4000)
plt.title("x projection", fontsize = 12) # change the title
plt.xlabel('x, pixel',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()

# %%
#Defines array for number of entries in each bin for baseline

#returns as a tuple
x1bY = plt.hist(x1b, bins = 256, range = (0, 256))

#converts tuple to list
x1bYList = list(x1bY[0])
x1bYI = [int(i) for i in x1bYList]

#Creates lists of background as X and Y points
X1BX = []; X1BY = []
for i in range(256):
    if x1bYI[i] != 0:
        X1BY.append(x1bYI[i])
        X1BX.append(i)
    else:
        print(i)

print (len(X1BX), len(X1BY))

# %%
#Finds line of best fit for arrays based on entire array

bf1 = np.polyfit(X1BX, X1BY, 1)
print(bf1)

bfx1 = np.linspace(0, 256, 10000)
def f(bfx1): return bf1[0]*bfx1 + bf1[1]

# %%
plt.rcParams["figure.figsize"] = (8,8)


plt.scatter(X1BX, X1BY, label = 'GaAs1')
plt.plot(bfx1, f(bfx1))
plt.fill_between(bfx1, f(bfx1), where = [(bfx1 >= x1min) and (bfx1 <= x1max) for bfx1 in bfx1], alpha = 0.3)
plt.fill_between(bfx1, f(bfx1), where = [(bfx1 >= x2min) and (bfx1 <= x2max) for bfx1 in bfx1], alpha = 0.3)
plt.legend()
plt.show()

# %%
bf1deg2 = np.polyfit(X1BX, X1BY, 2)
print(bf1deg2)

bf1xdeg2 = np.linspace(0, 256, 10000)
def g(bf1xdeg2): return bf1deg2[2] + bf1deg2[1]*bf1xdeg2 + bf1deg2[0] * bf1xdeg2**2

# %%
plt.rcParams["figure.figsize"] = (8,8)

#plt.scatter(X1BX, X1BY, label = 'GaAs1')
plt.plot(bf1xdeg2, g(bf1xdeg2), color = 'red')
#plt.fill_between(bf1xdeg2, g(bf1xdeg2), where = [(bf1xdeg2 >= x1min) and (bf1xdeg2 <= x1max) for bf1xdeg2 in bf1xdeg2], color = 'blue', alpha = 0.3)
#plt.fill_between(bf1xdeg2, g(bf1xdeg2), where = [(bf1xdeg2 >= x2min) and (bf1xdeg2 <= x2max) for bf1xdeg2 in bf1xdeg2], color = 'blue', alpha = 0.3)
plt.ylim(0,120000)
plt.show()

# %%
import sympy as sy

bf1xdeg2 = sy.Symbol('bf1xdeg2')

area_Under_1 = sy.integrate(g(bf1xdeg2), (bf1xdeg2, x1min, x1max))
print (area_Under_1)

area_Under_2 = sy.integrate(g(bf1xdeg2), (bf1xdeg2, x2min, x2max))
print (area_Under_2)

# %%
Peak_Area_1 = len(x1p1) - area_Under_1
print ('Area under first peak, subtracting background is', Peak_Area_1)
Peak_Area_2 = len(x1p2) - area_Under_2
print ('Area under second peak, subtracting background is', Peak_Area_2)
