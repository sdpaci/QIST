# %%
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import glob
import time
import pandas as pd
from statistics import mean

print (time.ctime())
# Out:
# Fri Sep 25 11:40:38 2020

# %%
# file1 = "/home/imaginglab/Data/TPX3/CHIP0/Test/8x8Grid_visEq_1s_W0028_F03-200228-095644-1.csv"
file1 ="/QuantumRouter/AOD8212020/AOM_64_10kHz_ext_W0028_H07-140105-025044-1_cent.csv"
print (file1, time.ctime())

# data1=np.loadtxt(file1, dtype= float, delimiter=",", usecols = (0,1,2,3,4))
# data1 = np.genfromtxt(file1, delimiter=",", skip_header=True)[:, 1:]
data1 = pd.read_csv(file1)
print(pd.read_csv(file1, nrows=5))
print(time.ctime())
# #print data
# y1   = data1.iloc[:, 0]
# x1   = data1.iloc[:, 1]
# t1   = data1.iloc[:, 2]
# a1   = data1.iloc[:, 3]
# A1   = data1.iloc[:, 4]

# for i in range(0,20):
#     print (i, x1[i],y1[i],t1[i],a1[i],A1[i])
    
# print (len(t1), time.ctime())

# file2 = "/home/imaginglab/Data/TPX3/CHIP0/Test/8x8Grid_SettingsEq_1s_W0028_F03-200228-100050-1.csv"
file2 = "/QuantumRouter/AOD8212020/AOM_64n_10kHz_ext_W0028_H07-140105-025447-1_cent.csv"
print (file2, time.ctime())

# data2=np.loadtxt(file2, dtype= float, delimiter=",", usecols = (0,1,2,3,4))
# data2 = np.genfromtxt(file2, delimiter=",", skip_header=True)[:, 1:]
data2 =pd.read_csv(file2)
print(pd.read_csv(file2, nrows=5))
print(time.ctime())
# #print data
# y2  = data2.iloc[:, 0]
# x2  = data2.iloc[:, 1]
# t2  = data2.iloc[:, 2]
# a2  = data2.iloc[:, 3]
# A2  = data2.iloc[:, 4]

# for i in range(0,20):
#     print (i, x2[i],y2[i],t2[i],a2[i],A2[i])
    
# print (len(t2), time.ctime())
# Out:
# /QuantumRouter/AOD8212020/AOM_64_10kHz_ext_W0028_H07-140105-025044-1_cent.csv Fri Sep 25 11:40:38 2020
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 0   101    55  162887602944       3950         1097650        193         NaN
# 1   101   159  162887602944       1900            7850          3         NaN
# 2   101   154  162887602944       1850            1875          2         NaN
# 3   100   149  162887602944       1775            4475          3         NaN
# 4   101   170  162887603200         25              25          1         NaN
# Fri Sep 25 11:40:43 2020
# /QuantumRouter/AOD8212020/AOM_64n_10kHz_ext_W0028_H07-140105-025447-1_cent.csv Fri Sep 25 11:40:43 2020
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 0   182    80  148749084416         75              75          1         NaN
# 1   198    69  148749119744         25              25          1         NaN
# 2   174    73  148749211392        150             150          1         NaN
# 3   195    63  148749250560         25              25          1         NaN
# 4   179    96  148749251584        150             150          1         NaN
# Fri Sep 25 11:40:45 2020

# %%
data1.shape, data2.shape
# Out:
# ((10680280, 7), (3400844, 7))

# %%
# file1 ="/QuantumRouter/AOD8212020/AOM_64_10kHz_ext_W0028_H07-140105-025044-1.csv"
GridX1min = 146
GridX1max = 191
GridY1min = 82
GridY1max = 127

# file2 = "/QuantumRouter/AOD8212020/AOM_64n_10kHz_ext_W0028_H07-140105-025447-1.csv"
GridX2min = 62
GridX2max = 107
GridY2min = 161
GridY2max = 206

# %%
#File 1 grid
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

h = ax0.hist2d(data1['#Row'], data1['#Col'], bins = 256, range = [(0, 256), (0, 256)])
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(data1['#Row'], data1['#Col'], bins = 256, range = [(0, 256), (0, 256)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)
fig.tight_layout()
plt.show()

# %%
#File 2 grid
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

h = ax0.hist2d(data2['#Row'], data2['#Col'], bins = 256, range = [(0, 256), (0, 256)])
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(data2['#Row'], data2['#Col'], bins = 256, range = [(0, 256), (0, 256)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)
fig.tight_layout()
plt.show()

# %%
#File 1 grid

# GridX1min = 145
# GridX1max = 180
# GridY1min = 80
# GridY1max = 125

# GridX1min = 60
# GridX1max = 105
# GridY1min = 155
# GridY1max = 198

# file1 ="/QuantumRouter/AOD8252020/AOD_blnkext_10kHz_20Dty_10sW0028_H07-140109-221335-1.csv"
# GridX1min = 100
# GridX1max = 150
# GridY1min = 110
# GridY1max = 160

fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

h = ax0.hist2d(data1['#Row'], data1['#Col'], bins = GridX1max-GridX1min, range = [(GridX1min, GridX1max), (GridY1min, GridY1max)])
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(data1['#Row'], data1['#Col'], bins = GridX1max-GridX1min, range = [(GridX1min, GridX1max), (GridY1min, GridY1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

fig.tight_layout()
plt.show()
fig.savefig('fullgrid_8212020_025044-1_cent.png')

# %%
#File 2 grid

# GridX2min = 62
# GridX2max = 107
# GridY2min = 161
# GridY2max = 206

# GridX2min = 60
# GridX2max = 105
# GridY2min = 155
# GridY2max = 198

# file2 = "/QuantumRouter/AOD8212020/AOM_64_10kHz_ext_W0028_H07-140105-025044-1.csv"
# GridX2min = 145
# GridX2max = 180
# GridY2min = 80
# GridY2max = 125

fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

h = ax0.hist2d(data2['#Row'], data2['#Col'], bins = GridX2max-GridX2min, range = [(GridX2min, GridX2max), (GridY2min, GridY2max)])
fig.colorbar(h[3], ax = ax0)

h = ax1.hist2d(data2['#Row'], data2['#Col'], bins = GridX2max-GridX2min, range = [(GridX2min, GridX2max), (GridY2min, GridY2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

fig.tight_layout()
plt.show()
fig.savefig('fullgrid_8212020_025447-1_cent.png')

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 40

plt.hist(data1['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 1', color = 'blue')
plt.hist(data2['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

plt.xlabel('ToT, ns')
plt.legend()
plt.show()
fig.savefig('TOT_025044-1_cent_vs_025447-1_cent_8212020.png')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
(n, bins, patches) = plt.hist(data1['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.xticks(bins)
plt.show()
# fig.savefig('TOA_256x256_8212020_025044-1_cent.png')


fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
(n, bins, patches) = plt.hist(data1['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.xticks(bins)
plt.show()

# Extinction Ratio


#fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(tt/4096.*25., bins = 100, color = 'r', ec = 'k')
#plt.title("TOA", fontsize = 12) # change the title
#plt.xlabel('TOA, ns',fontsize = 12)
#plt.ylabel('counts',fontsize = 12)
#plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(t/4096.*25., bins = 10, range = (0.5E+9, 1.5E+9), color = 'r', ec = 'k')
plt.hist(data1['#ToA']/4096.*25., bins = 1000, range = (-1.E+9, 1.E+9), color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(data2['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_256x256_8212020_025447-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
(n, bins, patches) = plt.hist(data2['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins[::40], rotation='vertical')
plt.show()

#fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(tt/4096.*25., bins = 100, color = 'r', ec = 'k')
#plt.title("TOA", fontsize = 12) # change the title
#plt.xlabel('TOA, ns',fontsize = 12)
#plt.ylabel('counts',fontsize = 12)
#plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(t/4096.*25., bins = 10, range = (0.5E+9, 1.5E+9), color = 'r', ec = 'k')
plt.hist(data2['#ToA']/4096.*25., bins = 1000, range = (-1.E+9, 1.E+9), color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()

# %%
(1.582e9-1.456e9)
# Out:
# 126000000.0

# %%
# r1 = t1[len(t1)//2:]/4096*25
# f1 = a1[len(a1)//2:]
plt.rcParams["figure.figsize"] = (20,6)
#len(t) = 8550085 
#
#plt.scatter(r,f)
plt.plot(data1['#ToA']/4096.*25.,data1['#ToT[arb]'], '')
#plt.plot(r, f, 'xb-')
#plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOA(ns)',fontsize = 12)
plt.ylabel('TOT',fontsize = 12)
# plt.xlim(0.75e10, 0.9e10)
plt.xlim(1e9, 1.03e9)
plt.savefig('TOTvsTOA_256x256_8212020_025044-1_cent.png', bbox_inches='tight')
time.ctime()
# Out:
# 'Fri Sep 25 11:41:07 2020'

# %%
# r1 = t1[len(t1)//2:]/4096*25
# f1 = a1[len(a1)//2:]
plt.rcParams["figure.figsize"] = (20,6)
#len(t) = 8550085 
#
#plt.scatter(r,f)
plt.plot(data2['#ToA']/4096.*25.,data2['#ToT[arb]'], '')
#plt.plot(r, f, 'xb-')
#plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOA(ns)',fontsize = 12)
plt.ylabel('TOT',fontsize = 12)
# plt.xlim(0.75e10, 0.9e10)
# plt.xlim(1e9, 1.03e9)
plt.savefig('TOTvsTOA_256x256_8212020_025447-1_cent.png', bbox_inches='tight')
time.ctime()
# Out:
# 'Fri Sep 25 11:41:12 2020'

# %%
# # #Sort arrays to exclude points outside Grid


# #Initialize trash arrays
# Grid_x1trash = []
# Grid_y1trash = []
# Grid_t1trash = []
# Grid_a1trash = []
# Grid_A1trash = []

# #Sort out points NOT in 8x8 Grid, add to trash
# for i in range(len(x1)):
#     if (GridY1min > y1[i]):
#         x1.drop(i)
#         y1.drop(i)
#         t1.drop(i)
#         a1.drop(i)
#         A1.drop(i)
#     elif (GridY1max < y1[i]):
#         x1.drop(i)
#         y1.drop(i)
#         t1.drop(i)
#         a1.drop(i)
#         A1.drop(i)
#     elif (GridX1min > x1[i]):
#         x1.drop(i)
#         y1.drop(i)
#         t1.drop(i)
#         a1.drop(i)
#         A1.drop(i)
#     elif (GridX1max < x1[i]):
#         x1.drop(i)
#         y1.drop(i)
#         t1.drop(i)
#         a1.drop(i)
#         A1.drop(i)

# for i in len(x1):
#     if (y[i] < GridY1min) || (y[i] < GridY1min)

# %%
def min_max(data, grid_x_min, grid_x_max, grid_y_min, grid_y_max):
    """Returns DataFrame filtering values less than min or greater than max for two columns"""
    x_cond = (data['#Row'] <grid_x_min) | (data['#Row'] > grid_x_max)
    y_cond = (data['#Col'] < grid_y_min) | (data['#Col'] > grid_y_max)
    new_data = data.drop(data[x_cond | y_cond].index)
    return new_data

grid1_df = min_max(data1, GridX1min, GridX1max, GridY1min, GridY1max)

print(grid1_df.shape, type(grid1_df.iloc[0,0]), type(grid1_df.iloc[1,1]), time.ctime())
print(grid1_df.iloc[:3])

grid2_df = min_max(data2, GridX2min, GridX2max, GridY2min, GridY2max)

print(grid2_df.shape, type(grid2_df.iloc[0,0]), type(grid2_df.iloc[1,1]), time.ctime())
print(grid2_df.iloc[:3])
# Out:
# (808919, 7) <class 'numpy.int64'> <class 'numpy.int64'> Fri Sep 25 11:41:17 2020
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 1   101   159  162887602944       1900            7850          3         NaN
# 2   101   154  162887602944       1850            1875          2         NaN
# 3   100   149  162887602944       1775            4475          3         NaN
# (3395280, 7) <class 'numpy.int64'> <class 'numpy.int64'> Fri Sep 25 11:41:17 2020
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 0   182    80  148749084416         75              75          1         NaN
# 1   198    69  148749119744         25              25          1         NaN
# 2   174    73  148749211392        150             150          1         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 20

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

(n, bins, patches) = plt.hist(grid1_df['#Centroid'], bins= nbins, range = [0, 25], color = 'orange', ec = 'k')
plt.title("Centroid", fontsize = 12) # change the title
plt.xlabel('Centroid size (pixels)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')
plt.xticks(bins, rotation='vertical')
# plt.xlabel('ToT, ns')
# plt.legend()
print('Min:', grid1_df['#Centroid'].min())
print('Max:', grid1_df['#Centroid'].max())
print('Avg:', grid1_df['#Centroid'].mean())
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')
# Out:
# Min: 1
# Max: 24
# Avg: 1.2691938253397435

# %%
# Grid_y1 = grid1_df.iloc[:, 0]
# Grid_x1 = grid1_df.iloc[:, 1]
# Grid_t1 = grid1_df.iloc[:, 2]
# Grid_a1 = grid1_df.iloc[:, 3]
# Grid_A1 = grid1_df.iloc[:, 4]

# %%
# Grid_y2 = grid2_df.iloc[:, 0]
# Grid_x2 = grid2_df.iloc[:, 1]
# Grid_t2 = grid2_df.iloc[:, 2]
# Grid_a2 = grid2_df.iloc[:, 3]
# Grid_A2 = grid2_df.iloc[:, 4]

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(10, 3))

ax0.hist(grid1_df['#Row'], bins = GridX1max-GridX1min, range = (GridX1min, GridX1max), color = 'g', alpha=0.5, histtype = 'stepfilled')
plt.title("x", fontsize = 12) # change the title
plt.xlabel('x, pixel',fontsize = 12)
plt.ylabel('counts',fontsize = 12)

ax1.hist(grid1_df['#Col'], bins = GridY1max-GridY1min, range = (GridY1min, GridY1max), color = 'g', alpha=0.5, histtype = 'stepfilled')
plt.title("y", fontsize = 12) # change the title
plt.xlabel('y, pixel',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# Out:
# Text(0,0.5,'counts')

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(10, 3))

ax0.hist(grid2_df['#Row'], bins = GridX2max-GridX2min, range = (GridX2min, GridX2max), color = 'g', alpha=0.5, histtype = 'stepfilled')
plt.title("x", fontsize = 12) # change the title
plt.xlabel('x, pixel',fontsize = 12)
plt.ylabel('counts',fontsize = 12)

ax1.hist(grid2_df['#Col'], bins = GridY2max-GridY2min, range = (GridY2min, GridY2max), color = 'g', alpha=0.5, histtype = 'stepfilled')
plt.title("y", fontsize = 12) # change the title
plt.xlabel('y, pixel',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# Out:
# Text(0,0.5,'counts')

# %%
#Define column segregations

C1min = GridX1min; C1max = C1min + 5;
C2min = C1max + 1; C2max = C2min + 4;
C3min = C2max + 1; C3max = C3min + 4;
C4min = C3max + 1; C4max = C4min + 5;
C5min = C4max + 1; C5max = C5min + 5;
C6min = C5max + 1; C6max = C6min + 5;
C7min = C6max + 1; C7max = C7min + 5;
C8min = C7max + 1; C8max = C8min + 5;

#Defime Row segregations

R1min = GridY1min; R1max = R1min + 5;
R2min = R1max + 1; R2max = R2min + 4;
R3min = R2max + 1; R3max = R3min + 4;
R4min = R3max + 1; R4max = R4min + 5;
R5min = R4max + 1; R5max = R5min + 5;
R6min = R5max + 1; R6max = R6min + 5;
R7min = R6max + 1; R7max = R7min + 4;
R8min = R7max + 1; R8max = R8min + 5;

# %%
# Display Row 1
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = [C1max+1-C1min, R1max+1-R1min], range = [(C1min, C1max+1), (R1min, R1max+1)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R1min, R1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax2)

h = ax3.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C3max-C3min, range = [(C3min, C3max), (R1min, R1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax3)

h = ax4.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C4max-C4min, range = [(C4min, C4max), (R1min, R1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax4)

fig.tight_layout()
plt.show()

fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax5.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C5max-C5min, range = [(C5min, C5max), (R1min, R1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax5)

h = ax6.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C6max-C6min, range = [(C6min, C6max), (R1min, R1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax6)

h = ax7.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C7max-C7min, range = [(C7min, C7max), (R1min, R1max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax7)

h = ax8.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C8max-C8min, range = [(C8min, C8max), (R1min, R1max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax8)

fig.tight_layout()
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:412: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:417: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1034: RuntimeWarning: divide by zero encountered in log
#   resdat -= np.log(vmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1035: RuntimeWarning: divide by zero encountered in log
#   resdat /= (np.log(vmax) - np.log(vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(5, 4))

h = ax0.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = [C1max+1-C1min, R1max+1-R1min], range = [(C1min, C1max+1), (R1min, R1max+1)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax0)
fig.tight_layout()
print("Point 1-1")
plt.show()
# fig.savefig('Pt1-1_8212020_025044-1_cent.png')
# Out:
# Point 1-1

# %%
Pt1_df = min_max(data1, C1min, C1max+1, R1min, R1max+1)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt1_df.shape, type(Pt1_df.iloc[0,0]), type(Pt1_df.iloc[1,1]), time.ctime())
print(Pt1_df.iloc[:3])
# Out:
# (15029, 7) <class 'numpy.int64'> <class 'numpy.int64'> Fri Sep 25 11:41:22 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 1503    84   149  162901323520       8425           24500          7
# 1766    88   149  162901489664        325             325          1
# 2203    85   150  162901671680        325             325          1
#
#       Unnamed: 6
# 1503         NaN
# 1766         NaN
# 2203         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt1_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980500e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
9.980500e8-9.980475e8, (48575+9.98e8)-(47800+9.98e8), 9.981475e8-9.980475e8, 2500/10000, 775/10000
# Out:
# (2500.0, 775.0, 100000.0, 0.25, 0.0775)

# %%
# range = (.998e9, 1e9)
ToAmin = (0.998e9)*4096./25.
ToAmax = (1e9)*4096./25.
Pt1_ToA_0pt998e9_1e9_df = Pt1_df.drop(Pt1_df[(Pt1_df['#ToA'] < ToAmin) | (Pt1_df['#ToA'] > ToAmax)].index)

print(Pt1_ToA_0pt998e9_1e9_df.shape, type(Pt1_ToA_0pt998e9_1e9_df.iloc[0,0]), type(Pt1_ToA_0pt998e9_1e9_df.iloc[1,1]), time.ctime())
print(Pt1_ToA_0pt998e9_1e9_df.iloc[:3])
# Out:
# (51, 7) <class 'numpy.int64'> <class 'numpy.int64'> Fri Sep 25 11:53:19 2020
#        #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 43665    84   149  163520152064       7675           10950          2
# 43855    83   148  163520276480        200             200          1
# 44914    83   149  163536548608        950             950          1
#
#        Unnamed: 6
# 43665         NaN
# 43855         NaN
# 44914         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

(n, bins, patches) = plt.hist(Pt1_ToA_0pt998e9_1e9_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'yellow', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')
plt.xticks(bins, rotation='vertical')
# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

# bins = Pt1_ToA_0pt998e9_1e9_df.shape[0]

h = ax0.hist2d(Pt1_ToA_0pt998e9_1e9_df['#Row'], Pt1_ToA_0pt998e9_1e9_df['#Col'], weights =Pt1_ToA_0pt998e9_1e9_df['#ToT[arb]'], bins = [C1max+1-C1min, R1max+1-R1min], range = [(C1min, C1max+1), (R1min, R1max+1)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax0)
h = ax1.hist2d(Pt1_ToA_0pt998e9_1e9_df['#Row'], Pt1_ToA_0pt998e9_1e9_df['#Col'], weights =Pt1_ToA_0pt998e9_1e9_df['#ToA'], bins = [C1max+1-C1min, R1max+1-R1min], range = [(C1min, C1max+1), (R1min, R1max+1)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)
fig.tight_layout()
print("Point 1-1")
plt.show()
# fig.savefig('Pt1-1_8212020_025044-1_cent.png')
# Out:
# Point 1-1

# %%
# Pt1_ToA_0.998e9-1e9_df = min_max(data1, C1min, C1max+1, R1min, R1max+1) range = (.998e9, 1e9) 9.9847800e8 9.9847825e8
ToAmin = (9.980475e8)*4096./25.
ToAmax = (9.980500e8)*4096./25.
Pt1_ToA_9pt980475e8_9pt9840500e8_df = Pt1_df.drop(Pt1_df[(Pt1_df['#ToA'] < ToAmin) | (Pt1_df['#ToA'] > ToAmax)].index)

print(Pt1_ToA_9pt980475e8_9pt9840500e8_df.shape, type(Pt1_ToA_9pt980475e8_9pt9840500e8_df.iloc[0,0]), type(Pt1_ToA_9pt980475e8_9pt9840500e8_df.iloc[1,1]), time.ctime())
print(Pt1_ToA_9pt980475e8_9pt9840500e8_df.iloc[:3])
# Out:
# (2, 7) <class 'numpy.int64'> <class 'numpy.int64'> Fri Sep 25 13:12:01 2020
#        #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 43665    84   149  163520152064       7675           10950          2
# 43855    83   148  163520276480        200             200          1
#
#        Unnamed: 6
# 43665         NaN
# 43855         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

(n, bins, patches) = plt.hist(Pt1_ToA_9pt980475e8_9pt9840500e8_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'yellow', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')
plt.xticks(bins, rotation='vertical')
# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(9.5, 4))

# bins = Pt1_ToA_0pt998e9_1e9_df.shape[0]

h = ax0.hist2d(Pt1_ToA_9pt980475e8_9pt9840500e8_df['#Row'], Pt1_ToA_9pt980475e8_9pt9840500e8_df['#Col'], weights =Pt1_ToA_9pt980475e8_9pt9840500e8_df['#ToT[arb]'], bins = [C1max+1-C1min, R1max+1-R1min], range = [(C1min, C1max+1), (R1min, R1max+1)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax0)
h = ax1.hist2d(Pt1_ToA_9pt980475e8_9pt9840500e8_df['#Row'], Pt1_ToA_9pt980475e8_9pt9840500e8_df['#Col'], weights =Pt1_ToA_9pt980475e8_9pt9840500e8_df['#ToA'], bins = [C1max+1-C1min, R1max+1-R1min], range = [(C1min, C1max+1), (R1min, R1max+1)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)
fig.tight_layout()
print("Point 1-1")
plt.show()
# fig.savefig('Pt1-1_8212020_025044-1_cent.png')
# Out:
# Point 1-1

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 20

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

(n, bins, patches) = plt.hist(Pt1_ToA_9pt980475e8_9pt9840500e8_df['#Centroid'], bins= nbins, range = [0, 5], color = 'orange', ec = 'k')
plt.title("Centroid", fontsize = 12) # change the title
plt.xlabel('Centroid size (pixels)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')
plt.xticks(bins, rotation='vertical')
# plt.xlabel('ToT, ns')
# plt.legend()
print('Min:', Pt1_ToA_9pt980475e8_9pt9840500e8_df['#Centroid'].min())
print('Max:', Pt1_ToA_9pt980475e8_9pt9840500e8_df['#Centroid'].max())
print('Avg:', Pt1_ToA_9pt980475e8_9pt9840500e8_df['#Centroid'].mean())
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')
# Out:
# Min: 1
# Max: 2
# Avg: 1.5

# %%
Pt2_R1_df = min_max(grid1_df, C2min, C2max, R1min, R1max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt2_R1_df.shape, type(Pt2_R1_df.iloc[0,0]), type(Pt2_R1_df.iloc[1,1]), time.ctime())
print(Pt2_R1_df.iloc[:3])
# Out:
# (17267, 7) <class 'numpy.int64'> <class 'numpy.int64'> Mon Sep 28 13:13:27 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 97      84   155  162887985664         75              75          1
# 1508    84   154  162901323008       8375           23875          7
# 1914    85   153  162901573888         25              25          1
#
#       Unnamed: 6
# 97           NaN
# 1508         NaN
# 1914         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt2_R1_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt2_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt2_R1_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt2_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt2_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980525e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt3_R1_df = min_max(grid1_df, C3min, C3max, R1min, R1max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt3_R1_df.shape, type(Pt3_R1_df.iloc[0,0]), type(Pt3_R1_df.iloc[1,1]), time.ctime())
print(Pt3_R1_df.iloc[:3])
# Out:
# (24920, 7) <class 'numpy.int64'> <class 'numpy.int64'> Mon Sep 28 13:17:59 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 119     84   161  162888003840        150             150          1
# 1504    84   159  162901329920       9000           32050         10
# 1762    83   159  162901488384         50              50          1
#
#       Unnamed: 6
# 119          NaN
# 1504         NaN
# 1762         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt3_R1_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt3_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt3_R1_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt3_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt3_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980525e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt4_R1_df = min_max(grid1_df, C4min, C4max, R1min, R1max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt4_R1_df.shape, type(Pt4_R1_df.iloc[0,0]), type(Pt4_R1_df.iloc[1,1]), time.ctime())
print(Pt4_R1_df.iloc[:3])
# Out:
# (17369, 7) <class 'numpy.int64'> <class 'numpy.int64'> Mon Sep 28 13:21:35 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 1527    84   165  162901344256       4150            8925          4
# 1647    84   166  162901426432         75              75          1
# 2169    85   165  162901655808        450             450          1
#
#       Unnamed: 6
# 1527         NaN
# 1647         NaN
# 2169         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt4_R1_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt4_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt4_R1_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt4_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt4_R1_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980525e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
#Display Row 2

fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C1max-C1min, range = [(C1min, C1max), (R2min, R2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R2min, R2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax2)

h = ax3.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C3max-C3min, range = [(C3min, C3max), (R2min, R2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax3)

h = ax4.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C4max-C4min, range = [(C4min, C4max), (R2min, R2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax4)

fig.tight_layout()
plt.show()

fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax5.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C5max-C5min, range = [(C5min, C5max), (R2min, R2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax5)

h = ax6.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C6max-C6min, range = [(C6min, C6max), (R2min, R2max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax6)

h = ax7.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C7max-C7min, range = [(C7min, C7max), (R2min, R2max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax7)

h = ax8.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C8max-C8min, range = [(C8min, C8max), (R2min, R2max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax8)

fig.tight_layout()
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:412: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:417: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1034: RuntimeWarning: divide by zero encountered in log
#   resdat -= np.log(vmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1035: RuntimeWarning: divide by zero encountered in log
#   resdat /= (np.log(vmax) - np.log(vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
Pt1_R2_df = min_max(grid1_df, C1min, C1max, R2min, R2max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt1_R2_df.shape, type(Pt1_R2_df.iloc[0,0]), type(Pt1_R2_df.iloc[1,1]), time.ctime())
print(Pt1_R2_df.iloc[:3])
# Out:
# (19605, 7) <class 'numpy.int64'> <class 'numpy.int64'> Mon Sep 28 13:26:19 2020
#      #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 29     90   149  162887609856       2225            2225          1
# 115    90   150  162887991040        200             200          1
# 610    90   149  162892105216       4825            4825          1
#
#      Unnamed: 6
# 29          NaN
# 115         NaN
# 610         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt1_R2_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt1_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt1_R2_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt1_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt1_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980525e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt2_R2_df = min_max(grid1_df, C2min, C2max, R2min, R2max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt2_R2_df.shape, type(Pt2_R2_df.iloc[0,0]), type(Pt2_R2_df.iloc[1,1]), time.ctime())
print(Pt2_R2_df.iloc[:3])
# Out:
# (15970, 7) <class 'numpy.int64'> <class 'numpy.int64'> Mon Sep 28 13:32:10 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 26      89   154  162887609600        200             200          1
# 1487    90   154  162901301248      14000           53375          9
# 1732    88   154  162901474816        225             225          1
#
#       Unnamed: 6
# 26           NaN
# 1487         NaN
# 1732         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt2_R2_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt2_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt2_R2_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt2_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt2_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.981450e8, 9.981475e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
'AOM platform Height (mm) (old):', 84.19, 'AOM platform Height (mm) (new):', 95.54, 'Difference (mm):', 95.54-84.19
# Out:
# ('AOM platform Height (mm) (old):',
#  84.19,
#  'AOM platform Height (mm) (new):',
#  95.54,
#  'Difference (mm):',
#  11.350000000000009)

# %%
'Camera vertical screw height (mm) (old):', 57.94, 'Camera vertical screw height (mm) (old) - 11.35:', 57.94-11.35
# Out:
# ('Camera vertical screw height (mm) (old):',
#  57.94,
#  'Camera vertical screw height (mm) (old) - 11.35:',
#  46.589999999999996)

# %%
'Camera vertical height top to breadboard (mm) (old):', 141.58, 'Camera vertical height top to breadboard (mm) (old) + 11.35:', 141.58+11.35
# Out:
# ('Camera vertical height top to breadboard (mm) (old):',
#  141.58,
#  'Camera vertical height top to breadboard (mm) (old) + 11.35:',
#  152.93)

# %%
'Laser mount from post distance (mm) (old):', 6.32, 'Laser mount from post distance (mm) (old) + 11.35:', 6.32+11.35
# Out:
# ('Laser mount from post distance (mm) (old):',
#  6.32,
#  'Laser mount from post distance (mm) (old) + 11.35:',
#  17.67)

# %%
Pt3_R2_df = min_max(grid1_df, C3min, C3max, R2min, R2max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt3_R2_df.shape, type(Pt3_R2_df.iloc[0,0]), type(Pt3_R2_df.iloc[1,1]), time.ctime())
print(Pt3_R2_df.iloc[:3])
# Out:
# (22968, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 12:52:35 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 72      89   161  162888002560        200             575          3
# 1482    90   159  162901304320      13575           63800         11
# 1719    89   161  162901470720         50              50          1
#
#       Unnamed: 6
# 72           NaN
# 1482         NaN
# 1719         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt3_R2_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt3_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt3_R2_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt3_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt3_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.981450e8, 9.981475e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt4_R2_df = min_max(grid1_df, C4min, C4max, R2min, R2max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt4_R2_df.shape, type(Pt4_R2_df.iloc[0,0]), type(Pt4_R2_df.iloc[1,1]), time.ctime())
print(Pt4_R2_df.iloc[:3])
# Out:
# (16912, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 12:53:41 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 1501    90   165  162901319680       5100           18275          7
# 2017    91   165  162901606144        100             125          2
# 2056    89   163  162901616640         50              50          1
#
#       Unnamed: 6
# 1501         NaN
# 2017         NaN
# 2056         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt4_R2_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt4_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt4_R2_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt4_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt4_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.981450e8, 9.981475e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt5_R2_df = min_max(grid1_df, C5min, C5max, R2min, R2max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt5_R2_df.shape, type(Pt5_R2_df.iloc[0,0]), type(Pt5_R2_df.iloc[1,1]), time.ctime())
print(Pt5_R2_df.iloc[:3])
# Out:
# (14566, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 12:55:43 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 91      90   171  162887979008        100             100          1
# 1486    90   170  162901305344       5650           30750          9
# 2762    89   171  162902010368        250             250          1
#
#       Unnamed: 6
# 91           NaN
# 1486         NaN
# 2762         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt5_R2_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt5_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt5_R2_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt5_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt5_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.981450e8, 9.981475e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt6_R2_df = min_max(grid1_df, C6min, C6max, R2min, R2max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt6_R2_df.shape, type(Pt6_R2_df.iloc[0,0]), type(Pt6_R2_df.iloc[1,1]), time.ctime())
print(Pt6_R2_df.iloc[:3])
# Out:
# (19855, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 12:56:44 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 1555    90   175  162901340672       1175            2575          5
# 1808    89   175  162901599488        175             250          4
# 2331    90   174  162901704448         25              25          1
#
#       Unnamed: 6
# 1555         NaN
# 1808         NaN
# 2331         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt6_R2_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt6_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt6_R2_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt6_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt6_R2_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.981450e8, 9.981475e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
#Display Row 3

fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C1max-C1min, range = [(C1min, C1max), (R3min, R3max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R3min, R3max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax2)

h = ax3.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C3max-C3min, range = [(C3min, C3max), (R3min, R3max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax3)

h = ax4.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C4max-C4min, range = [(C4min, C4max), (R3min, R3max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax4)

fig.tight_layout()
plt.show()

fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax5.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C5max-C5min, range = [(C5min, C5max), (R3min, R3max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax5)

h = ax6.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C6max-C6min, range = [(C6min, C6max), (R3min, R3max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax6)

h = ax7.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C7max-C7min, range = [(C7min, C7max), (R3min, R3max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax7)

h = ax8.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C8max-C8min, range = [(C8min, C8max), (R3min, R3max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax8)

fig.tight_layout()
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:412: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:417: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1034: RuntimeWarning: divide by zero encountered in log
#   resdat -= np.log(vmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1035: RuntimeWarning: divide by zero encountered in log
#   resdat /= (np.log(vmax) - np.log(vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
Pt1_R3_df = min_max(grid1_df, C1min, C1max, R3min, R3max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt1_R3_df.shape, type(Pt1_R3_df.iloc[0,0]), type(Pt1_R3_df.iloc[1,1]), time.ctime())
print(Pt1_R3_df.iloc[:3])
# Out:
# (17141, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 13:31:21 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 113     95   150  162887990784        200             200          1
# 1496    95   149  162901314560      13175           36125          9
# 1876    95   147  162901564928        150             150          1
#
#       Unnamed: 6
# 113          NaN
# 1496         NaN
# 1876         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt1_R3_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt1_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt1_R3_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt1_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt1_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980500e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt2_R3_df = min_max(grid1_df, C2min, C2max, R3min, R3max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt2_R3_df.shape, type(Pt2_R3_df.iloc[0,0]), type(Pt2_R3_df.iloc[1,1]), time.ctime())
print(Pt2_R3_df.iloc[:3])
# Out:
# (15107, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 13:33:11 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 1505    95   154  162901313280       9225           27450          7
# 1873    96   155  162901562880        600             600          1
# 1899    94   155  162901571328        575             575          1
#
#       Unnamed: 6
# 1505         NaN
# 1873         NaN
# 1899         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt2_R3_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt2_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt2_R3_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt2_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt2_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980500e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt3_R3_df = min_max(grid1_df, C3min, C3max, R3min, R3max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt3_R3_df.shape, type(Pt3_R3_df.iloc[0,0]), type(Pt3_R3_df.iloc[1,1]), time.ctime())
print(Pt3_R3_df.iloc[:3])
# Out:
# (19183, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 13:35:24 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 89      96   160  162887978240        125             225          2
# 1500    95   159  162901313536      16100           42425          9
# 1929    95   158  162901647872        675             900          3
#
#       Unnamed: 6
# 89           NaN
# 1500         NaN
# 1929         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt3_R3_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt3_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt3_R3_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt3_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt3_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980500e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt4_R3_df = min_max(grid1_df, C4min, C4max, R3min, R3max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt4_R3_df.shape, type(Pt4_R3_df.iloc[0,0]), type(Pt4_R3_df.iloc[1,1]), time.ctime())
print(Pt4_R3_df.iloc[:3])
# Out:
# (15596, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 13:38:36 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 1515    95   165  162901326592       4050           12550          5
# 1933    96   164  162901577216        500             500          1
# 2070    94   164  162901617920        175             175          1
#
#       Unnamed: 6
# 1515         NaN
# 1933         NaN
# 2070         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt4_R3_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt4_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt4_R3_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt4_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt4_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980500e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt5_R3_df = min_max(grid1_df, C5min, C5max, R3min, R3max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt5_R3_df.shape, type(Pt5_R3_df.iloc[0,0]), type(Pt5_R3_df.iloc[1,1]), time.ctime())
print(Pt5_R3_df.iloc[:3])
# Out:
# (13922, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 13:39:33 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 1506    95   170  162901314048       4850           15800          6
# 1888    96   171  162901567744         75              75          1
# 1982    94   169  162901597952        275             275          1
#
#       Unnamed: 6
# 1506         NaN
# 1888         NaN
# 1982         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt5_R3_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt5_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt5_R3_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt5_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt5_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980500e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
Pt6_R3_df = min_max(grid1_df, C6min, C6max, R3min, R3max)
# Pt1_ToT_df = grid1_df.drop(grid1_df[(grid1_df['#ToT[arb]'] > tMin2) & (grid1_df['#ToT[arb]'] < tMax2)].index)

print(Pt6_R3_df.shape, type(Pt6_R3_df.iloc[0,0]), type(Pt6_R3_df.iloc[1,1]), time.ctime())
print(Pt6_R3_df.iloc[:3])
# Out:
# (17400, 7) <class 'numpy.int64'> <class 'numpy.int64'> Tue Sep 29 13:44:26 2020
#       #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 1564    95   175  162901358336        725             975          2
# 2048    95   175  162901615360        275             300          2
# 3334    95   175  162917665024        325             600          2
#
#       Unnamed: 6
# 1564         NaN
# 2048         NaN
# 3334         NaN

# %%
fig, ax1 = plt.subplots(ncols=1, figsize=(20, 8))

nbins = 100

# ax0.hist(a, bins = 100, range = (0, 2500), color = 'r', ec = 'k')
# plt.title("TOT", fontsize = 12) # change the title
# plt.xlabel('TOT(ns)',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)

plt.hist(Pt6_R3_df['#ToT[arb]'], bins= nbins, range = [0, 10000], color = 'r', ec = 'k')
plt.title("TOT", fontsize = 12) # change the title
plt.xlabel('TOT(ns)',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
# plt.hist(Pt1_df['#ToT[arb]'], bins= nbins, range = [0, 20000], lw=3, histtype='step', label = 'file 2', color = 'red')

# plt.xlabel('ToT, ns')
# plt.legend()
plt.show()
# fig.savefig('TOT_Pt1-1_025044-1_cent_8212020.png',  bbox_inches='tight')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt6_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_2s_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(Pt6_R3_df['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
# fig.savefig('TOA_20pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt6_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_3pks_Pt1-1_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(Pt6_R3_df['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.980475e8, 9.980500e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# fig.savefig('TOA_1pk_Pt1-1_8212020_025044-1_cent.png')

# %%
#Display Row 4

fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C1max-C1min, range = [(C1min, C1max), (R4min, R4max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R4min, R4max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax2)

h = ax3.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C3max-C3min, range = [(C3min, C3max), (R4min, R4max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax3)

h = ax4.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C4max-C4min, range = [(C4min, C4max), (R4min, R4max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax4)

fig.tight_layout()
plt.show()

fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax5.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C5max-C5min, range = [(C5min, C5max), (R4min, R4max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax5)

h = ax6.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C6max-C6min, range = [(C6min, C6max), (R4min, R4max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax6)

h = ax7.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C7max-C7min, range = [(C7min, C7max), (R4min, R4max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax7)

h = ax8.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C8max-C8min, range = [(C8min, C8max), (R4min, R4max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax8)

fig.tight_layout()
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:412: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:417: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1034: RuntimeWarning: divide by zero encountered in log
#   resdat -= np.log(vmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1035: RuntimeWarning: divide by zero encountered in log
#   resdat /= (np.log(vmax) - np.log(vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
#Display Row 5

fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C1max-C1min, range = [(C1min, C1max), (R5min, R5max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R5min, R5max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax2)

h = ax3.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C3max-C3min, range = [(C3min, C3max), (R5min, R5max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax3)

h = ax4.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C4max-C4min, range = [(C4min, C4max), (R5min, R5max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax4)

fig.tight_layout()
plt.show()

fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax5.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C5max-C5min, range = [(C5min, C5max), (R5min, R5max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax5)

h = ax6.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C6max-C6min, range = [(C6min, C6max), (R5min, R5max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax6)

h = ax7.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C7max-C7min, range = [(C7min, C7max), (R5min, R5max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax7)

h = ax8.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C8max-C8min, range = [(C8min, C8max), (R5min, R5max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax8)

fig.tight_layout()
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:412: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:417: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1034: RuntimeWarning: divide by zero encountered in log
#   resdat -= np.log(vmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1035: RuntimeWarning: divide by zero encountered in log
#   resdat /= (np.log(vmax) - np.log(vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
#Display Row 6

fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C1max-C1min, range = [(C1min, C1max), (R6min, R6max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R6min, R6max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax2)

h = ax3.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C3max-C3min, range = [(C3min, C3max), (R6min, R6max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax3)

h = ax4.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C4max-C4min, range = [(C4min, C4max), (R6min, R6max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax4)

fig.tight_layout()
plt.show()

fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax5.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C5max-C5min, range = [(C5min, C5max), (R6min, R6max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax5)

h = ax6.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C6max-C6min, range = [(C6min, C6max), (R6min, R6max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax6)

h = ax7.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C7max-C7min, range = [(C7min, C7max), (R6min, R6max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax7)

h = ax8.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C8max-C8min, range = [(C8min, C8max), (R6min, R6max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax8)

fig.tight_layout()
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:412: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:417: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1034: RuntimeWarning: divide by zero encountered in log
#   resdat -= np.log(vmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1035: RuntimeWarning: divide by zero encountered in log
#   resdat /= (np.log(vmax) - np.log(vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
#Display Row 7

fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C1max-C1min, range = [(C1min, C1max), (R7min, R7max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax1)

h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R7min, R7max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax2)

h = ax3.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C3max-C3min, range = [(C3min, C3max), (R7min, R7max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax3)

h = ax4.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C4max-C4min, range = [(C4min, C4max), (R7min, R7max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax4)

fig.tight_layout()
plt.show()

fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

h = ax5.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C5max-C5min, range = [(C5min, C5max), (R7min, R7max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax5)

h = ax6.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C6max-C6min, range = [(C6min, C6max), (R7min, R7max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax6)

h = ax7.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C7max-C7min, range = [(C7min, C7max), (R7min, R7max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax7)

h = ax8.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C8max-C8min, range = [(C8min, C8max), (R7min, R7max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax8)

fig.tight_layout()
plt.show()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:412: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py:417: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1034: RuntimeWarning: divide by zero encountered in log
#   resdat -= np.log(vmin)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:1035: RuntimeWarning: divide by zero encountered in log
#   resdat /= (np.log(vmax) - np.log(vmin))
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
# #Display Row 8

# fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(20, 4))

# h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C1max-C1min, range = [(C1min, C1max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax1)

# h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax2)

# h = ax3.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C3max-C3min, range = [(C3min, C3max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax3)

# h = ax4.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C4max-C4min, range = [(C4min, C4max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax4)

# fig.tight_layout()
# plt.show()

# fig, (ax5, ax6, ax7, ax8) = plt.subplots(ncols=4, figsize=(20, 4))

# h = ax5.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C5max-C5min, range = [(C5min, C5max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax5)

# h = ax6.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C6max-C6min, range = [(C6min, C6max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# fig.colorbar(h[3], ax = ax6)

# h = ax7.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C7max-C7min, range = [(C7min, C7max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# # fig.colorbar(h[3], ax = ax7)

# h = ax8.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C8max-C8min, range = [(C8min, C8max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# # fig.colorbar(h[3], ax = ax8)

# fig.tight_layout()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-f778affeb76f> in <module>()
#       4
#       5 h = ax1.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C1max-C1min, range = [(C1min, C1max), (R8min, R8max)], norm=mpl.colors.LogNorm())
# ----> 6 fig.colorbar(h[3], ax = ax1)
#       7
#       8 h = ax2.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = C2max-C2min, range = [(C2min, C2max), (R8min, R8max)], norm=mpl.colors.LogNorm())
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2069                              'panchor']
#    2070         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2071         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2072
#    2073         self.sca(current_ax)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1397         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1398     else:
# -> 1399         cb = Colorbar(cax, mappable, **kwargs)
#    1400
#    1401     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colorbar.py in __init__(self, ax, mappable, **kw)
#     943                 kw['alpha'] = mappable.get_alpha()
#     944
# --> 945             ColorbarBase.__init__(self, ax, **kw)
#     946
#     947     def on_mappable_changed(self, mappable):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colorbar.py in __init__(self, ax, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     325         # The rest is in a method so we can recalculate when clim changes.
#     326         self.config_axis()
# --> 327         self.draw_all()
#     328
#     329     def _extend_lower(self):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colorbar.py in draw_all(self)
#     351         X, Y = self._mesh()
#     352         C = self._values[:, np.newaxis]
# --> 353         self._config_axes(X, Y)
#     354         if self.filled:
#     355             self._add_solids(X, Y, C)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colorbar.py in _config_axes(self, X, Y)
#     459         ax.add_artist(self.patch)
#     460
# --> 461         self.update_ticks()
#     462
#     463     def _set_label(self):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colorbar.py in update_ticks(self)
#     376         """
#     377         ax = self.ax
# --> 378         ticks, ticklabels, offset_string = self._ticker()
#     379         if self.orientation == 'vertical':
#     380             ax.yaxis.set_ticks(ticks)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colorbar.py in _ticker(self)
#     620         formatter.set_data_interval(*intv)
#     621
# --> 622         b = np.array(locator())
#     623         if isinstance(locator, ticker.LogLocator):
#     624             eps = 1e-10
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2087         'Return the locations of the ticks'
#    2088         vmin, vmax = self.axis.get_view_interval()
# -> 2089         return self.tick_values(vmin, vmax)
#    2090
#    2091     def tick_values(self, vmin, vmax):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\ticker.py in tick_values(self, vmin, vmax)
#    2113             if vmin <= 0.0 or not np.isfinite(vmin):
#    2114                 raise ValueError(
# -> 2115                     "Data has no positive values, and therefore can not be "
#    2116                     "log-scaled.")
#    2117
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000247364BDA60> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def draw_cursor(self, event):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in draw(self, renderer, *args, **kwargs)
#     591         else:
#     592             im, l, b, trans = self.make_image(
# --> 593                 renderer, renderer.get_image_magnification())
#     594             if im is not None:
#     595                 renderer.draw_image(gc, l, b, im)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in make_image(self, renderer, magnification, unsampled)
#     839         return self._make_image(
#     840             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 841             unsampled=unsampled)
#     842
#     843     def _check_unsampled_image(self, renderer):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     487
#     488                 # mask and run through the norm
# --> 489                 output = self.norm(np.ma.masked_array(A_resampled, out_mask))
#     490             else:
#     491                 # Always convert to RGBA, even if only RGB input
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py in __call__(self, value, clip)
#    1015             raise ValueError("minvalue must be less than or equal to maxvalue")
#    1016         elif vmin <= 0:
# -> 1017             raise ValueError("values must all be positive")
#    1018         elif vmin == vmax:
#    1019             result.fill(0)
#
# ValueError: values must all be positive
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     511
#     512     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 513         FigureCanvasAgg.draw(self)
#     514         renderer = self.get_renderer()
#     515         original_dpi = renderer.dpi
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in draw(self, renderer, *args, **kwargs)
#     591         else:
#     592             im, l, b, trans = self.make_image(
# --> 593                 renderer, renderer.get_image_magnification())
#     594             if im is not None:
#     595                 renderer.draw_image(gc, l, b, im)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in make_image(self, renderer, magnification, unsampled)
#     839         return self._make_image(
#     840             self._A, bbox, transformed_bbox, self.axes.bbox, magnification,
# --> 841             unsampled=unsampled)
#     842
#     843     def _check_unsampled_image(self, renderer):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     487
#     488                 # mask and run through the norm
# --> 489                 output = self.norm(np.ma.masked_array(A_resampled, out_mask))
#     490             else:
#     491                 # Always convert to RGBA, even if only RGB input
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\colors.py in __call__(self, value, clip)
#    1015             raise ValueError("minvalue must be less than or equal to maxvalue")
#    1016         elif vmin <= 0:
# -> 1017             raise ValueError("values must all be positive")
#    1018         elif vmin == vmax:
#    1019             result.fill(0)
#
# ValueError: values must all be positive

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(12, 4))

h = ax0.hist2d(grid1_df['#Row'], grid1_df['#Col'], bins = [C3max-C1min, R1max-R1min], range = [(C1min, C3max), (R1min, R1max)])
fig.colorbar(h[3], ax = ax0)

fig.tight_layout()
plt.show()

# %%
#define tmin, tmax
# tMin0 = 0.9990e9
# tMax0 = 0.999125e9

tMin0 = 0.9990e9
tMax0 = 3e9

ToA_df0 = grid1_df.drop(grid1_df[(grid1_df['#ToA'] > tMin0) & (grid1_df['#ToA'] < tMax0)].index)

print(ToA_df0.shape, type(ToA_df0.iloc[0,0]), type(ToA_df0.iloc[1,1]), time.ctime())
print(ToA_df0.iloc[:3])
# Out:
# (808919, 7) <class 'numpy.int64'> <class 'numpy.int64'> Wed Sep 23 14:29:15 2020
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 1   101   159  162887602944       1900            7850          3         NaN
# 2   101   154  162887602944       1850            1875          2         NaN
# 3   100   149  162887602944       1775            4475          3         NaN

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(12, 4))

h = ax0.hist2d(ToA_df0['#Row'], ToA_df0['#Col'], bins = [C3max-C1min, R1max-R1min], range = [(C1min, C3max), (R1min, R1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax0)

fig.tight_layout()
plt.show()
fig.savefig('PtsC1-3_R1_tstep0.99e9-3e9_8212020_025044-1_cent.png')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(ToA_df0['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
fig.savefig('TOA_PtsC1-3_R1_tstep0.99e9-3e9_8212020_025044-1_cent.png')

#fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(tt/4096.*25., bins = 100, color = 'r', ec = 'k')
#plt.title("TOA", fontsize = 12) # change the title
#plt.xlabel('TOA, ns',fontsize = 12)
#plt.ylabel('counts',fontsize = 12)
#plt.show()

# fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
# #plt.hist(t/4096.*25., bins = 10, range = (0.5E+9, 1.5E+9), color = 'r', ec = 'k')
# plt.hist(ToA_df0['#ToA']/4096.*25., bins = 1000, range = (-1.E+9, 1.E+9), color = 'r', ec = 'r')
# plt.title("TOA", fontsize = 12) # change the title
# plt.xlabel('TOA, ns',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)
# plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(ToA_df0['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
fig.savefig('TOA_3pks_PtsC1-3_R1_tstep0.99e9-3e9_8212020_025044-1_cent.png')

# fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
# plt.hist(ToA_df0['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (2.0e9, 300000+2.0e9))
# plt.title("TOA", fontsize = 12) # change the title
# plt.xlabel('TOA, ns',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)
# plt.show()

# %%
#define tmin, tmax
tStep = tMax0-tMin0;
tMin1 = tMax0
tMax1 = tMin1 + tStep;

ToA_df1 = grid1_df.drop(grid1_df[(grid1_df['#ToA'] > tMin1) & (grid1_df['#ToA'] < tMax1)].index)

print(ToA_df1.shape, type(ToA_df1.iloc[0,0]), type(ToA_df1.iloc[1,1]), time.ctime())
print(ToA_df1.iloc[:3])
# Out:
# (808919, 7) <class 'numpy.int64'> <class 'numpy.int64'> Wed Sep 23 15:08:17 2020
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 1   101   159  162887602944       1900            7850          3         NaN
# 2   101   154  162887602944       1850            1875          2         NaN
# 3   100   149  162887602944       1775            4475          3         NaN

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(12, 4))

h = ax0.hist2d(ToA_df1['#Row'], ToA_df1['#Col'], bins = [C3max-C1min, R1max-R1min], range = [(C1min, C3max), (R1min, R1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax0)

fig.tight_layout()
plt.show()
fig.savefig('PtsC1-3_R1_tstep3e9-5e9_8212020_025044-1_cent.png')

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(ToA_df1['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
fig.savefig('TOA_PtsC1-3_R1_tstep3e9-5e9_8212020_025044-1_cent.png')

#fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
#plt.hist(tt/4096.*25., bins = 100, color = 'r', ec = 'k')
#plt.title("TOA", fontsize = 12) # change the title
#plt.xlabel('TOA, ns',fontsize = 12)
#plt.ylabel('counts',fontsize = 12)
#plt.show()

# fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
# #plt.hist(t/4096.*25., bins = 10, range = (0.5E+9, 1.5E+9), color = 'r', ec = 'k')
# plt.hist(ToA_df1['#ToA']/4096.*25., bins = 1000, range = (-1.E+9, 1.E+9), color = 'r', ec = 'r')
# plt.title("TOA", fontsize = 12) # change the title
# plt.xlabel('TOA, ns',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)
# plt.show()

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(ToA_df1['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (0.998e9, 0.99825e9))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
fig.savefig('TOA_3pks_PtsC1-3_R1_tstep3e9-5e9_8212020_025044-1_cent.png')

# %%
#define tmin, tmax
tMin2 = tMax1
tMax2 = tMin2 + tStep;

ToA_df2 = grid1_df.drop(grid1_df[(grid1_df['#ToA'] > tMin2) & (grid1_df['#ToA'] < tMax2)].index)

print(ToA_df2.shape, type(ToA_df2.iloc[0,0]), type(ToA_df2.iloc[1,1]), time.ctime())
print(ToA_df2.iloc[:3])
# Out:
# (808919, 7) <class 'numpy.int64'> <class 'numpy.int64'> Wed Sep 23 15:08:19 2020
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 1   101   159  162887602944       1900            7850          3         NaN
# 2   101   154  162887602944       1850            1875          2         NaN
# 3   100   149  162887602944       1775            4475          3         NaN

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(12, 4))

h = ax0.hist2d(ToA_df2['#Row'], ToA_df2['#Col'], bins = [C3max-C1min, R1max-R1min], range = [(C1min, C3max), (R1min, R1max)], norm=mpl.colors.LogNorm())
fig.colorbar(h[3], ax = ax0)

fig.tight_layout()
plt.show()
fig.savefig('PtsC1-3_R1_tstep5e9-7e9_8212020_025044-1_cent.png')

# %%
from statistics import mean
a = 9.98045
b = 9.98070
b-a
lst1 = [5,8,3,4,6,4,8,2]
m1 = mean(lst1)
lst2 = [5,8,6,2,8,6,4,1,5,5,3]
m2 = mean(lst2)
lst3 = lst1+lst2
m1, m2, m1+m2, lst3, mean(lst3)
# Out:
# (5,
#  4.818181818181818,
#  9.818181818181818,
#  [5, 8, 3, 4, 6, 4, 8, 2, 5, 8, 6, 2, 8, 6, 4, 1, 5, 5, 3],
#  4.894736842105263)

# %%
0.99825e9-0.998e9
# Out:
# 250000.0

# %%
fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(ToA_df2['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
fig.savefig('TOA_PtsC1-3_R1_tstep5e9-7e9_8212020_025044-1_cent.png')

fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.show()
fig.savefig('TOA_2s_PtsC1-3_R1_tstep5e9-7e9_8212020_025044-1_cent.png')

# fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
# plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'k', range = (.998e9, 3e9))
# plt.title("TOA", fontsize = 12) # change the title
# plt.xlabel('TOA, ns',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)
# plt.show()

# fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
# #plt.hist(t/4096.*25., bins = 10, range = (0.5E+9, 1.5E+9), color = 'r', ec = 'k')
# plt.hist(ToA_df2['#ToA']/4096.*25., bins = 1000, range = (-1.E+9, 1.E+9), color = 'r', ec = 'r')
# plt.title("TOA", fontsize = 12) # change the title
# plt.xlabel('TOA, ns',fontsize = 12)
# plt.ylabel('counts',fontsize = 12)
# plt.show()

range_start = 0.998e9
range_stop = 0.99830e9
print('1')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (range_start, range_stop))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()

# [::2]

range_start = range_stop
range_stop = range_stop+300000
print('2')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (range_start, range_stop))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()

range_start = range_stop
range_stop = range_stop+300000
print('3')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (range_start, range_stop))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()

range_start = range_stop
range_stop = range_stop+300000
print('4')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (range_start, range_stop))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()

range_start = range_stop
range_stop = range_stop+300000
print('5')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (range_start, range_stop))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()

range_start = range_stop
range_stop = range_stop+300000
print('6')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (range_start, range_stop))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
fig.savefig('TOA_3pks_grp6_PtsC1-3_R1_tstep5e9-7e9_8212020_025044-1_cent.png')

range_start = range_stop
range_stop = range_stop+170000
print('7')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (range_start, range_stop))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
fig.savefig('TOA_3pks_grp7_PtsC1-3_R1_tstep5e9-7e9_8212020_025044-1_cent.png')
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
print('6')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.99500e8, 9.99800e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
# Out:
# 6

# %%
print('6_1')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.99536e8, 9.99554e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
fig.savefig('TOA_1pk_grp6-1_PtsC1-3_R1_tstep5e9-7e9_8212020_025044-1_cent.png')
# Out:
# 6_1

# %%
print('7_1')
fig, ax0 = plt.subplots(ncols=1, figsize=(20, 4))
(n, bins, patches) = plt.hist(ToA_df2['#ToA']/4096.*25., bins = 100, color = 'r', ec = 'r', range = (9.998357e8, 9.998510e8))
#plt.hist(ToA_C1R1_file1/4096.*25., bins = 1000, color = 'r', ec = 'r')
plt.title("TOA", fontsize = 12) # change the title
plt.xlabel('TOA, ns',fontsize = 12)
plt.ylabel('counts',fontsize = 12)
plt.xticks(bins, rotation='vertical')
plt.show()
fig.savefig('TOA_1pk_grp7-1_PtsC1-3_R1_tstep5e9-7e9_8212020_025044-1_cent.png')
# Out:
# 7_1

# %%
# range_start = 0.998e9
# range_stop = 
0.99830e9-0.998e9
# Out:
# 300000.0

# %%
9.981450e8-9.980450e8, 9.99800e8-9.99698e8, 9.980625e8-9.980450e8
# Out:
# (100000.0, 102000.0, 17500.0)

# %%
five_3_a = 9.99437e8
five_3_b = 9.99455e8
six_1_a = 9.99536e8
six_1_b = 9.99554e8
six_1_a-five_3_a
# Out:
# 99000.0

# %%
six_3_a = 9.99737e8
six_3_b = 9.99758e8
seven_1_a = 9.998357e8
seven_1_b = 9.998510e8
seven_1_a-six_3_a
# Out:
# 98700.0

# %%
seven_1_a = 9.998357e8
seven_1_b = 9.998510e8
seven_2_a = 9.999343e8
seven_2_b = 9.999496e8
seven_2_a-seven_1_a, seven_1_b-seven_1_a
# Out:
# (98600.0, 15300.0)

# %%
9.981450e8+100000, 9.981450e8+100000+100000, 9.981450e8+100000+100000+100000, 9.981450e8+100000+100000+100000+100000
# Out:
# (998245000.0, 998345000.0, 998445000.0, 998545000.0)

# %%
from statistics import mean 
# Or convert to list first
# ER_ToA_df2 = ToA_df2['#ToA'].tolist()
# ER_ToA_df2 = ER_ToA_df2[(ER_ToA_df2 <9.98045) | (ER_ToA_df2 <9.98070)]
a = (9.980450e8)*4096./25.
b = (9.980625e8)*4096./25. #??????????????????????
a1 = (9.981440e8)*4096./25.
b1 = (9.981620e8)*4096./25.
c = a1-a

#list
print("ToA_df2['#ToA'].mean():", ToA_df2['#ToA'].mean())
toa = ToA_df2.loc[:, '#ToA']
toa_conv = toa/4096.*25.
highlevellst = []
lowlevellst = []
# highlevellst = [i for i in toa if a<i<b]
for i in toa:
    if (a<i<b):
        highlevellst.append(i)
# lowlevellst = [i for i in toa if i not in highlevellst]
print("len(toa):", len(toa))
print("mean(toa_conv):", mean(toa_conv))
print('mean(toa):', mean(toa))
print('len(highlevellst):', len(highlevellst))
print('mean(highlevellst):', mean(highlevellst)) 
# print(len(lowlevellst), mean(lowlevellst))
# LowLeveldf = ToA_df2
# LowlevelSeries = ToA_df2['#ToA']
# HighLevelSeries = ToA_df2['#ToA']
# HighLevelSeries = pd.Series()
# temp = pd.Series()
# ToA_df2 = grid1_df.drop(grid1_df[(grid1_df['#ToA'] > tMin2) & (grid1_df['#ToA'] < tMax2)].index)
LowLeveldf = ToA_df2.drop(ToA_df2[(ToA_df2['#ToA'] > a) & (ToA_df2['#ToA'] < b)].index)
HighLeveldf = ToA_df2[(ToA_df2['#ToA'] > a) & (ToA_df2['#ToA'] < b)]
print(LowLeveldf.head())
print('Shape before loop', LowLeveldf.shape[0])
print(HighLeveldf.head())
print('Shape before loop', HighLeveldf.shape[0])
a = a + c
b = b + c
for i in range(39):
    # take in full array
    # remove one element at a time 
    LowLeveldf = LowLeveldf.drop(LowLeveldf[(LowLeveldf['#ToA'] > a) & (LowLeveldf['#ToA'] < b)].index)
    HighLeveldf = HighLeveldf.append(ToA_df2[(ToA_df2['#ToA'] > a) & (ToA_df2['#ToA'] < b)])
#     del ER_ToA_df2[a:b]
#     ER_ToA_df2 = ER_ToA_df2[a:b]
#     HighLevelSeries = HighLevelSeries.append(LowlevelSeries[(LowlevelSeries > a) & (LowlevelSeries < b)])
#     LowlevelSeries = LowlevelSeries.drop(LowlevelSeries[(LowlevelSeries > a) & (LowlevelSeries < b)].index)
#     temp = temp.append(HighLevelSeries[(HighLevelSeries > a) & (HighLevelSeries < b)])
    print(i, ":")
    print('LowLeveldf:')
    fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
    plt.hist(LowLeveldf['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
    plt.title("TOA", fontsize = 12) # change the title
    plt.xlabel('TOA, ns',fontsize = 12)
    plt.ylabel('counts',fontsize = 12)
    plt.show()
    print('LowLeveLdf zoom:')
    fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
    plt.hist(ToA_df2['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (a-c, b+c))
    plt.title("TOA", fontsize = 12) # change the title
    plt.xlabel('TOA, ns',fontsize = 12)
    plt.ylabel('counts',fontsize = 12)
    plt.show()
    print('HighLeveldf:')
    fig, ax0 = plt.subplots(ncols=1, figsize=(10, 4))
    plt.hist(HighLeveldf['#ToA']/4096.*25., bins = 1000, color = 'r', ec = 'r', range = (.998e9, 1e9))
    plt.title("TOA", fontsize = 12) # change the title
    plt.xlabel('TOA, ns',fontsize = 12)
    plt.ylabel('counts',fontsize = 12)
    plt.show()
    a = a + c
    b = b + c
# HighLevelSeries = temp
# LowLevelavg = LowLeveldf['#ToA'].mean()
LowLevelavg = LowLeveldf['#ToA'].mean()
# # ER_ToA_df2 = ToA_df2['#ToA']
# a = 9.98045
# b = 9.98070
# a1 = 9.98145 
# b1 = 9.98170
# c = a1-a
# temp = pd.Series()
# for i in range(20):
#     temp += ER_ToA_df2[a:b]
#     a = a + c
#     b = b + c
HighLevelavg = HighLeveldf['#ToA'].mean()
# print(HighLevelSeries.head())
print(LowLeveldf.head())
print('Shape after loop', LowLeveldf.shape[0])
print(HighLeveldf.head())
print('Shape after loop', HighLeveldf.shape[0])
print('')
print('LowLevelavg:', LowLevelavg)
print('HighLevelavg:', HighLevelavg)
# print("Gate Open/Closed ToA Ratio:", (HighLevelavg/LowLevelavg)*100, '%')
print("Gate Open/Closed ToA Ratio:", (HighLeveldf.shape[0]/LowLeveldf.shape[0])*100, '%')
# print('ToA as percentage of total (When gate is open):', (HighLevelavg/(LowLevelavg+HighLevelavg))*100, '%')
# print('ToA as percentage of total (When gate is closed):', (LowLevelavg/(LowLevelavg+HighLevelavg))*100, '%')
print('ToA as percentage of total (When gate is open):', (HighLeveldf.shape[0]/(len(toa)))*100, '%')
print('ToA as percentage of total (When gate is closed):', (LowLeveldf.shape[0]/(len(toa)))*100, '%')
# Out:
# ToA_df2['#ToA'].mean(): 245148696544.72437
# len(toa): 808919
# mean(toa_conv): 1496268899.8091087
# mean(toa): 245148696544.72437
# len(highlevellst): 77
# mean(highlevellst): 163520563688.72726
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 1   101   159  162887602944       1900            7850          3         NaN
# 2   101   154  162887602944       1850            1875          2         NaN
# 3   100   149  162887602944       1775            4475          3         NaN
# 4   101   170  162887603200         25              25          1         NaN
# 5   101   164  162887603200       1175            1175          1         NaN
# Shape before loop 808842
#        #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 43578   102   155  163520099328       1750            1750          1
# 43581   113   160  163520100096       2975            2975          1
# 43589   118   158  163520134912       2250            2575          2
# 43595   108   154  163520106240        350             350          1
# 43596   106   160  163520135936       9350           13275          3
#
#        Unnamed: 6
# 43578         NaN
# 43581         NaN
# 43589         NaN
# 43595         NaN
# 43596         NaN
# Shape before loop 77
# 0 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 1 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 2 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 3 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 4 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 5 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 6 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 7 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 8 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 9 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 10 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 11 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 12 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 13 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 14 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 15 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 16 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 17 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 18 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 19 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 20 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 21 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 22 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 23 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 24 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 25 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 26 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 27 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 28 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 29 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 30 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 31 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 32 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 33 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 34 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 35 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 36 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 37 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
# 38 :
# LowLeveldf:
# LowLeveLdf zoom:
# HighLeveldf:
#    #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  Unnamed: 6
# 1   101   159  162887602944       1900            7850          3         NaN
# 2   101   154  162887602944       1850            1875          2         NaN
# 3   100   149  162887602944       1775            4475          3         NaN
# 4   101   170  162887603200         25              25          1         NaN
# 5   101   164  162887603200       1175            1175          1         NaN
# Shape after loop 806460
#        #Col  #Row          #ToA  #ToT[arb]  #ToTtotal[arb]  #Centroid  \
# 43578   102   155  163520099328       1750            1750          1
# 43581   113   160  163520100096       2975            2975          1
# 43589   118   158  163520134912       2250            2575          2
# 43595   108   154  163520106240        350             350          1
# 43596   106   160  163520135936       9350           13275          3
#
#        Unnamed: 6
# 43578         NaN
# 43581         NaN
# 43589         NaN
# 43595         NaN
# 43596         NaN
# Shape after loop 2459
#
# LowLevelavg: 245396746344.65698
# HighLevelavg: 163797642598.54575
# Gate Open/Closed ToA Ratio: 0.3049128289065794 %
# ToA as percentage of total (When gate is open): 0.3039859367872432 %
# ToA as percentage of total (When gate is closed): 99.69601406321276 %
