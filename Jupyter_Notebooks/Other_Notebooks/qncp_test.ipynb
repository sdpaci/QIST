# %%
from qncp import acq, search

# %%
import pyvisa

rm = pyvisa.ResourceManager()

rm.list_resources()
# Out:
# ()

# %%
pip install pyUSB
# Out:
# Requirement already satisfied: pyUSB in /home/steven/.local/lib/python3.8/site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
search.list_resources()
# Out:
# ()

# %%
# search.get_resource('USB0::4883::32888::P0008411::0::INSTR')

# %%
#PM100 Power Meter: USB0::4883::32888::P0008411::0::INSTR
inst = pyvisa.ResourceManager().open_resource('USB0::4883::32888::P0008411::0::INSTR') 
inst
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1837/1046196396.py in <module>
#       1 #PM100 Power Meter: USB0::4883::32888::P0008411::0::INSTR
# ----> 2 inst = pyvisa.ResourceManager().open_resource('USB0::4883::32888::P0008411::0::INSTR')
#       3 inst
#
# ~/.local/lib/python3.8/site-packages/pyvisa/highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3282                     )
#    3283
# -> 3284             res.open(access_mode, open_timeout)
#    3285
#    3286             for key, value in kwargs.items():
#
# ~/.local/lib/python3.8/site-packages/pyvisa/resources/resource.py in open(self, access_mode, open_timeout)
#     276             constants.StatusCode.success_device_not_present
#     277         ):
# --> 278             self.session, status = self._resource_manager.open_bare_resource(
#     279                 self._resource_name, access_mode, open_timeout
#     280             )
#
# ~/.local/lib/python3.8/site-packages/pyvisa/highlevel.py in open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3207
#    3208         """
# -> 3209         return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#    3210
#    3211     def open_resource(
#
# ~/.local/lib/python3.8/site-packages/pyvisa_py/highlevel.py in open(self, session, resource_name, access_mode, open_timeout)
#     165         )
#     166
# --> 167         sess = cls(session, resource_name, parsed, open_timeout)
#     168
#     169         return self._register(sess), StatusCode.success
#
# ~/.local/lib/python3.8/site-packages/pyvisa_py/sessions.py in __init__(self, resource_manager_session, resource_name, parsed, open_timeout)
#     323         self.set_attribute(attr, default_timeout)
#     324
# --> 325         self.after_parsing()
#     326
#     327     def after_parsing(self) -> None:
#
# ~/.local/lib/python3.8/site-packages/pyvisa_py/usb.py in after_parsing(self)
#      79
#      80     def after_parsing(self) -> None:
# ---> 81         self.interface = self._intf_cls(
#      82             int(self.parsed.manufacturer_id, 0),
#      83             int(self.parsed.model_code, 0),
#
# ~/.local/lib/python3.8/site-packages/pyvisa_py/protocols/usbtmc.py in __init__(self, vendor, product, serial_number, **kwargs)
#     285
#     286     def __init__(self, vendor=None, product=None, serial_number=None, **kwargs):
# --> 287         super(USBTMC, self).__init__(vendor, product, serial_number, **kwargs)
#     288         self.usb_intr_in = find_endpoint(
#     289             self.usb_intf, usb.ENDPOINT_IN, usb.ENDPOINT_TYPE_INTERRUPT
#
# ~/.local/lib/python3.8/site-packages/pyvisa_py/protocols/usbtmc.py in __init__(self, vendor, product, serial_number, device_filters, timeout, **kwargs)
#     197
#     198         if not devices:
# --> 199             raise ValueError("No device found.")
#     200         elif len(devices) > 1:
#     201             desc = "\n".join(str(dev) for dev in devices)
#
# ValueError: No device found.

# %%
import usb.core
import usb.util

list(usb.core.find(find_all=True))
